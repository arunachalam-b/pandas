# %%
import utils

# %%
coffee = utils.readCoffeeData()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# coffee.head(3)
# coffee.loc[:, ["Day", "Units Sold"]]
# coffee.loc[2:8, ["Day", "Units Sold"]]
# coffee.iloc[2:8, [0, 2]] # It will not be inclusive of max index
# coffee.iloc[3:, 1:]
coffee.iloc[1, 2]
# Out:
# np.int64(15)

# %%
# coffee.at[7, "Coffee Type"]
# coffee.iat[7, 1]
# coffee.iat[:, :] # It will give error
# coffee.at[:, :] # It will give error
coffee.iat[1, 2]
# Out:
# np.int64(15)
